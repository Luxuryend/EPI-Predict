# %%
import pandas as pd

# %%
df = pd.read_csv('data/train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52288 entries, 0 to 52287
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   enhancer_name                  52288 non-null  object
#  1   enhancer_frag_seq              52288 non-null  object
#  2   promoter_name                  52288 non-null  object
#  3   promoter_frag_seq              52288 non-null  object
#  4   enhancer_distance_to_promoter  52288 non-null  int64
#  5   label                          52288 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 2.4+ MB

# %%
def one_hot_encode(s):
    maps = {'A': 0, 'C': 1, 'G': 2, 'T': 3}
    matrix = np.zeros((200, 4), dtype=np.int8)
    for i, j in enumerate(s):
        try:
            matrix[i, maps[j]] = 1
        except KeyError:
            continue
    return matrix
